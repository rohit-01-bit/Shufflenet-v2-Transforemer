# %%
# Import necessary libraries
import os
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling2D, Concatenate, Lambda, GlobalAveragePooling1D, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, confusion_matrix, classification_report
from imblearn.over_sampling import RandomOverSampler
import gc
from tensorflow.keras.losses import BinaryCrossentropy

# Constants
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32  # Reduced batch size to save memory
EPOCHS = 50
LEARNING_RATE = 1e-4
SMOOTHING = 0.7  # Label smoothing factor

# Enable mixed precision training
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# Restrict TensorFlow to only use needed GPU memory
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# Clear memory
gc.collect()
tf.keras.backend.clear_session()

# Paths
authentic_paths = [
    '/kaggle/input/defactosplicing/splicing_1_annotations/donor_mask',
    '/kaggle/input/defactosplicing/splicing_1_annotations/graph'
]
tampered_paths = [
    '/kaggle/input/defactosplicing/splicing_1_annotations/probe_mask'
]

# Load Data
def collect_image_files(authentic_paths, tampered_paths):
    authentic_files, tampered_files = [], []
    for path in authentic_paths + tampered_paths:
        for subdir, _, files in os.walk(path):
            for file in files:
                if file.lower().endswith(('.png', '.jpeg', '.jpg', '.tif')):
                    full_path = os.path.join(subdir, file)
                    (authentic_files if path in authentic_paths else tampered_files).append(full_path)
    print(f"Number of authentic images found: {len(authentic_files)}")
    print(f"Number of tampered images found: {len(tampered_files)}")
    return authentic_files, tampered_files

authentic_files, tampered_files = collect_image_files(authentic_paths, tampered_paths)
all_files = authentic_files + tampered_files
all_labels = [0] * len(authentic_files) + [1] * len(tampered_files)

print(f"Total images before oversampling: {len(all_files)}")

# Handle Imbalance
oversampler = RandomOverSampler(random_state=42)
all_files, all_labels = oversampler.fit_resample(np.array(all_files).reshape(-1, 1), np.array(all_labels))
all_files = all_files.flatten()

print(f"Total images after oversampling: {len(all_files)}")

# Split data
train_files, test_files, train_labels, test_labels = train_test_split(
    all_files, all_labels, test_size=0.2, random_state=42, stratify=all_labels)

print(f"Training images: {len(train_files)}")
print(f"Testing images: {len(test_files)}")

# Data Generator with Augmentation
class CustomImageDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, image_files, labels, batch_size, image_size, shuffle=True, augment=False):
        self.image_files = np.array(image_files)
        self.labels = np.array(labels).reshape(-1, 1)
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.augment = augment
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.image_files) / self.batch_size))

    def __getitem__(self, idx):
        batch_indices = self.indices[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_images, batch_labels = [], []
        for i in batch_indices:
            img = cv2.imread(self.image_files[i], cv2.IMREAD_GRAYSCALE)  # Read as grayscale
            if img is not None:
                img = cv2.resize(img, self.image_size)
                if self.augment:
                    img = self.augment_image(img)  # Apply augmentation
                batch_images.append(img)
                batch_labels.append(self.labels[i])
        return np.expand_dims(np.array(batch_images, dtype=np.float16) / 255.0, axis=-1), np.array(batch_labels)

    def augment_image(self, img):
        img = np.expand_dims(img, axis=-1)  # Add channel dimension
        img = tf.image.random_flip_left_right(img)
        img = tf.image.random_brightness(img, max_delta=0.1)
        img = tf.image.random_contrast(img, lower=0.8, upper=1.2)
        return img

    def on_epoch_end(self):
        self.indices = np.arange(len(self.image_files))
        if self.shuffle:
            np.random.shuffle(self.indices)

train_gen = CustomImageDataGenerator(train_files, train_labels, BATCH_SIZE, IMAGE_SIZE, augment=True)
test_gen = CustomImageDataGenerator(test_files, test_labels, BATCH_SIZE, IMAGE_SIZE, shuffle=False)

import numpy as np
import keras.backend as K
from keras.layers import Input, Conv2D, MaxPool2D, DepthwiseConv2D, BatchNormalization, Activation, Concatenate, GlobalAveragePooling2D, Dense, Lambda, Flatten, Reshape, MultiHeadAttention, Dropout, LayerNormalization, Add
from keras.models import Model

# Function for Channel Shuffle
def channel_shuffle(x):
    height, width, channels = x.shape.as_list()[1:]
    channels_per_split = channels // 2
    x = tf.reshape(x, [-1, height, width, 2, channels_per_split])
    x = tf.transpose(x, perm=(0, 1, 2, 4, 3))
    x = tf.reshape(x, [-1, height, width, channels])
    return x

# ShuffleNet Unit (Shuffle Block)
def shuffle_unit(inputs, out_channels, bottleneck_ratio, strides=2, stage=1, block=1):
    if K.image_data_format() == 'channels_last':
        bn_axis = -1
    else:
        raise ValueError('Only channels last supported')

    prefix = f'stage{stage}_block{block}'
    bottleneck_channels = int(out_channels * bottleneck_ratio)
    
    x = Conv2D(bottleneck_channels, kernel_size=(1,1), strides=1, padding='same', name=f'{prefix}_1x1conv_1')(inputs)
    x = BatchNormalization(axis=bn_axis, name=f'{prefix}_bn_1x1conv_1')(x)
    x = Activation('relu', name=f'{prefix}_relu_1x1conv_1')(x)
    
    x = DepthwiseConv2D(kernel_size=3, strides=strides, padding='same', name=f'{prefix}_3x3dwconv')(x)
    x = BatchNormalization(axis=bn_axis, name=f'{prefix}_bn_3x3dwconv')(x)
    
    x = Conv2D(bottleneck_channels, kernel_size=1, strides=1, padding='same', name=f'{prefix}_1x1conv_2')(x)
    x = BatchNormalization(axis=bn_axis, name=f'{prefix}_bn_1x1conv_2')(x)
    x = Activation('relu', name=f'{prefix}_relu_1x1conv_2')(x)

    ret = Lambda(channel_shuffle, output_shape=lambda s: s, name=f'{prefix}_channel_shuffle')(x)
    return ret

# Transformer Block
def TransformerBlock(inputs, num_heads=8, ff_dim=512, dropout_rate=0.1):
    attn_output = MultiHeadAttention(num_heads=num_heads, key_dim=inputs.shape[-1] // num_heads)(inputs, inputs)
    attn_output = Dropout(dropout_rate)(attn_output)
    out1 = Add()([inputs, attn_output])
    out1 = LayerNormalization(epsilon=1e-6)(out1)
    
    ffn_output = Dense(ff_dim, activation='relu')(out1)
    ffn_output = Dense(inputs.shape[-1])(ffn_output)  # Match input shape
    ffn_output = Dropout(dropout_rate)(ffn_output)
    
    out2 = Add()([out1, ffn_output])
    out2 = LayerNormalization(epsilon=1e-6)(out2)
    return out2

# ShuffleNetV2 Backbone
def ShuffleNetV2(input_shape=(32,32,3)):
    img_input = Input(shape=input_shape)
    
    x = Conv2D(24, kernel_size=(3, 3), padding='same', use_bias=False, strides=(2, 2), activation='relu', name='conv1')(img_input)
    x = MaxPool2D(pool_size=(3, 3), strides=(2, 2), padding='same', name='maxpool1')(x)
    x = shuffle_unit(x, out_channels=116, strides=2, bottleneck_ratio=1, stage=2, block=1)
    
    x = Conv2D(1024, kernel_size=1, padding='same', strides=1, activation='relu', name='conv_final')(x)
    x = GlobalAveragePooling2D(name='global_avg_pool')(x)
    
    return Model(img_input, x, name='ShuffleNetV2')

# Hybrid Model with ShuffleNet and Transformer
def HybridModel(input_shape=(224, 224, 1)):
    shufflenet = ShuffleNetV2(input_shape=input_shape)
    shufflenet_output = shufflenet.output  # (batch_size, features)

    # Reshape for Transformer block
    reshaped_output = Reshape((1, shufflenet_output.shape[-1]))(shufflenet_output)

    # Pass through Transformer block
    transformer_output = TransformerBlock(reshaped_output)

    # Flatten and classification layers
    transformer_output = Flatten()(transformer_output)
    x = Dense(512, activation='relu')(transformer_output)
    x = Dropout(0.3)(x)
    x = Dense(1, activation='sigmoid')(x)  # Single output neuron with sigmoid activation

    model = Model(inputs=shufflenet.input, outputs=x)
    return model

# Create and compile the model
model = HybridModel(input_shape=(224, 224, 1))
model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss=BinaryCrossentropy(label_smoothing=SMOOTHING),  # Use built-in function
    metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
)

# Print model summary
print(model.summary())

# Callbacks
class ClearMemory(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        gc.collect()
        tf.keras.backend.clear_session()

clear_memory = ClearMemory()

early_stopping = EarlyStopping(monitor='val_auc', patience=10, restore_best_weights=True, mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_auc', factor=0.5, patience=5, min_lr=1e-7, verbose=1, mode='max')
model_checkpoint = ModelCheckpoint('best_hybrid_model.keras', monitor='val_auc', mode='max', save_best_only=True, verbose=1)

# Train Model
history = model.fit(
    train_gen,
    validation_data=test_gen,
    epochs=EPOCHS,
    callbacks=[early_stopping, reduce_lr, model_checkpoint, clear_memory]
)

# Save the model
model.save('hybrid_model.keras')
print("Model saved as hybrid_model.keras")

# Evaluate Model
test_preds = model.predict(test_gen)
test_preds = (test_preds > 0.5).astype(int)  # Convert probabilities to binary predictions

# Calculate metrics
accuracy = accuracy_score(test_labels, test_preds)
precision = precision_score(test_labels, test_preds)
recall = recall_score(test_labels, test_preds)
f1 = f1_score(test_labels, test_preds)
roc_auc = roc_auc_score(test_labels, test_preds)

# Confusion Matrix
conf_matrix = confusion_matrix(test_labels, test_preds)

# Classification Report
class_report = classification_report(test_labels, test_preds, target_names=['Authentic', 'Tampered'])

# ROC Curve
fpr, tpr, thresholds = roc_curve(test_labels, test_preds)

# AUC Curve plotting
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC Curve (AUC = {roc_auc:.4f})', color='blue')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUC Curve')
plt.legend(loc='lower right')
plt.grid(alpha=0.3)
plt.show()

# Print all results
print("\n=== Evaluation Metrics ===")
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test F1-Score: {f1:.4f}")
print(f"Test ROC-AUC: {roc_auc:.4f}")

print("\n=== Confusion Matrix ===")
print(conf_matrix)

print("\n=== Classification Report ===")
print(class_report)

# Plot Confusion Matrix
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Authentic', 'Tampered'], yticklabels=['Authentic', 'Tampered'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Plot Precision, Recall, and F1-Score in a bar graph
metrics = ['Precision', 'Recall', 'F1-Score']
values = [precision, recall, f1]

plt.figure(figsize=(8, 5))
bars = plt.bar(metrics, values, color=['blue', 'green', 'orange'])

# Add values on top of the bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.4f}',
             ha='center', va='bottom', fontsize=10)

plt.title('Precision, Recall, and F1-Score')
plt.xlabel('Metrics')
plt.ylabel('Score')
plt.ylim(0, 1)  # Set y-axis limits between 0 and 1
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Plot Model Loss and Accuracy over Epochs
plt.figure(figsize=(10, 5))

# Plot Train vs Validation Accuracy
plt.figure(figsize=(8,5))
plt.plot(history.history['accuracy'], label='Train Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Train vs Validation Accuracy')
plt.legend()
plt.grid()
plt.show()

# Plot Train vs Validation Loss
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Train vs Validation Loss')
plt.legend()
plt.grid()
plt.show()

plt.tight_layout()
plt.show()
# Out:
# Number of authentic images found: 10765
# Number of tampered images found: 10765
# Total images before oversampling: 21530
# Total images after oversampling: 21530
# Training images: 17224
# Testing images: 4306
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 224, 224, 1)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1 (Conv2D)            │ (None, 112, 112, 24)   │            216 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ maxpool1 (MaxPooling2D)   │ (None, 56, 56, 24)     │              0 │ conv1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stage2_block1_1x1conv_1   │ (None, 56, 56, 116)    │          2,900 │ maxpool1[0][0]         │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stage2_block1_bn_1x1conv… │ (None, 56, 56, 116)    │            464 │ stage2_block1_1x1conv… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stage2_block1_relu_1x1co… │ (None, 56, 56, 116)    │              0 │ stage2_block1_bn_1x1c… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stage2_block1_3x3dwconv   │ (None, 28, 28, 116)    │          1,160 │ stage2_block1_relu_1x… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stage2_block1_bn_3x3dwco… │ (None, 28, 28, 116)    │            464 │ stage2_block1_3x3dwco… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stage2_block1_1x1conv_2   │ (None, 28, 28, 116)    │         13,572 │ stage2_block1_bn_3x3d… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stage2_block1_bn_1x1conv… │ (None, 28, 28, 116)    │            464 │ stage2_block1_1x1conv… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stage2_block1_relu_1x1co… │ (None, 28, 28, 116)    │              0 │ stage2_block1_bn_1x1c… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stage2_block1_channel_sh… │ (None, 28, 28, 116)    │              0 │ stage2_block1_relu_1x… │
# │ (Lambda)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv_final (Conv2D)       │ (None, 28, 28, 1024)   │        119,808 │ stage2_block1_channel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_avg_pool           │ (None, 1024)           │              0 │ conv_final[0][0]       │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape (Reshape)         │ (None, 1, 1024)        │              0 │ global_avg_pool[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention      │ (None, 1, 1024)        │      4,198,400 │ reshape[0][0],         │
# │ (MultiHeadAttention)      │                        │                │ reshape[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 1, 1024)        │              0 │ multi_head_attention[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 1, 1024)        │              0 │ reshape[0][0],         │
# │                           │                        │                │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization       │ (None, 1, 1024)        │          2,048 │ add[0][0]              │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 1, 512)         │        524,800 │ layer_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 1, 1024)        │        525,312 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 1, 1024)        │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 1, 1024)        │              0 │ layer_normalization[0… │
# │                           │                        │                │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_1     │ (None, 1, 1024)        │          2,048 │ add_1[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 1024)           │              0 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 512)            │        524,800 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 512)            │              0 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 1)              │            513 │ dropout_3[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 5,916,969 (22.57 MB)
#  Trainable params: 5,916,273 (22.57 MB)
#  Non-trainable params: 696 (2.72 KB)
# None
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 8, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 538/539 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.7522 - auc: 0.7992 - loss: 0.6961
# Epoch 1: val_auc improved from -inf to 0.90551, saving model to best_hybrid_model.keras
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 335s 592ms/step - accuracy: 0.7524 - auc: 0.7994 - loss: 0.6961 - val_accuracy: 0.8379 - val_auc: 0.9055 - val_loss: 0.6700 - learning_rate: 1.0000e-04
# Epoch 2/50
# 538/539 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.8538 - auc: 0.9104 - loss: 0.6685
# Epoch 2: val_auc improved from 0.90551 to 0.98110, saving model to best_hybrid_model.keras
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 147s 269ms/step - accuracy: 0.8539 - auc: 0.9105 - loss: 0.6685 - val_accuracy: 0.9192 - val_auc: 0.9811 - val_loss: 0.6607 - learning_rate: 1.0000e-04
# Epoch 3/50
# 538/539 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9244 - auc: 0.9676 - loss: 0.6598
# Epoch 3: val_auc improved from 0.98110 to 0.99459, saving model to best_hybrid_model.keras
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 150s 274ms/step - accuracy: 0.9245 - auc: 0.9677 - loss: 0.6598 - val_accuracy: 0.9673 - val_auc: 0.9946 - val_loss: 0.6535 - learning_rate: 1.0000e-04
# Epoch 4/50
# 538/539 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9452 - auc: 0.9825 - loss: 0.6560
# Epoch 4: val_auc improved from 0.99459 to 0.99747, saving model to best_hybrid_model.keras
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 147s 269ms/step - accuracy: 0.9452 - auc: 0.9825 - loss: 0.6560 - val_accuracy: 0.9682 - val_auc: 0.9975 - val_loss: 0.6520 - learning_rate: 1.0000e-04
# Epoch 5/50
# 538/539 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.9523 - auc: 0.9850 - loss: 0.6548
# Epoch 5: val_auc improved from 0.99747 to 0.99861, saving model to best_hybrid_model.keras
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 178s 327ms/step - accuracy: 0.9523 - auc: 0.9850 - loss: 0.6548 - val_accuracy: 0.9833 - val_auc: 0.9986 - val_loss: 0.6506 - learning_rate: 1.0000e-04
# Epoch 6/50
# 538/539 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9637 - auc: 0.9917 - loss: 0.6531
# Epoch 6: val_auc improved from 0.99861 to 0.99885, saving model to best_hybrid_model.keras
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 153s 280ms/step - accuracy: 0.9637 - auc: 0.9917 - loss: 0.6531 - val_accuracy: 0.9814 - val_auc: 0.9988 - val_loss: 0.6499 - learning_rate: 1.0000e-04
# Epoch 7/50
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9704 - auc: 0.9918 - loss: 0.6526
# Epoch 7: val_auc did not improve from 0.99885
# 539/539 ━━━━━━━━━━━━━━━━━━━━
# Epoch 26: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 26: val_auc did not improve from 0.99995
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 146s 268ms/step - accuracy: 0.9934 - auc: 0.9989 - loss: 0.6488 - val_accuracy: 0.9956 - val_auc: 0.9997 - val_loss: 0.6481 - learning_rate: 5.0000e-05
# Epoch 27/50
# 538/539 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9958 - auc: 0.9994 - loss: 0.6486
# Epoch 27: val_auc did not improve from 0.99995
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 145s 266ms/step - accuracy: 0.9958 - auc: 0.9994 - loss: 0.6486 - val_accuracy: 0.9963 - val_auc: 0.9996 - val_loss: 0.6481 - learning_rate: 2.5000e-05
# Epoch 28/50
# 538/539 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9954 - auc: 0.9992 - loss: 0.6486
# Epoch 28: val_auc did not improve from 0.99995
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 143s 262ms/step - accuracy: 0.9954 - auc: 0.9992 - loss: 0.6486 - val_accuracy: 0.9963 - val_auc: 0.9998 - val_loss: 0.6480 - learning_rate: 2.5000e-05
# Epoch 29/50
# 538/539 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9952 - auc: 0.9993 - loss: 0.6486
# Epoch 29: val_auc did not improve from 0.99995
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 153s 280ms/step - accuracy: 0.9952 - auc: 0.9993 - loss: 0.6486 - val_accuracy: 0.9967 - val_auc: 0.9991 - val_loss: 0.6479 - learning_rate: 2.5000e-05
# Epoch 30/50
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9945 - auc: 0.9993 - loss: 0.6486
# Epoch 30: val_auc did not improve from 0.99995
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 144s 263ms/step - accuracy: 0.9945 - auc: 0.9993 - loss: 0.6486 - val_accuracy: 0.9965 - val_auc: 0.9995 - val_loss: 0.6481 - learning_rate: 2.5000e-05
# Epoch 31/50
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9954 - auc: 0.9991 - loss: 0.6486
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 31: val_auc did not improve from 0.99995
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 152s 278ms/step - accuracy: 0.9954 - auc: 0.9991 - loss: 0.6486 - val_accuracy: 0.9965 - val_auc: 0.9993 - val_loss: 0.6480 - learning_rate: 2.5000e-05
# Epoch 32/50
# 538/539 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9966 - auc: 0.9993 - loss: 0.6484
# Epoch 32: val_auc did not improve from 0.99995
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 149s 272ms/step - accuracy: 0.9966 - auc: 0.9993 - loss: 0.6484 - val_accuracy: 0.9974 - val_auc: 0.9995 - val_loss: 0.6479 - learning_rate: 1.2500e-05
# Model saved as hybrid_model.keras
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (32, 8, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step
# === Evaluation Metrics ===
# Test Accuracy: 0.9956
# Test Precision: 1.0000
# Test Recall: 0.9912
# Test F1-Score: 0.9956
# Test ROC-AUC: 0.9956
#
# === Confusion Matrix ===
# [[2153    0]
#  [  19 2134]]
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#    Authentic       0.99      1.00      1.00      2153
#     Tampered       1.00      0.99      1.00      2153
#
#     accuracy                           1.00      4306
#    macro avg       1.00      1.00      1.00      4306
# weighted avg       1.00      1.00      1.00      4306
