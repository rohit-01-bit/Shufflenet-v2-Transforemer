# %%
import os
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling2D, Concatenate, Lambda, GlobalAveragePooling1D, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, confusion_matrix, classification_report
from imblearn.over_sampling import RandomOverSampler
import gc
from tensorflow.keras.losses import BinaryCrossentropy

# Constants
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32  # Reduced batch size to save memory
EPOCHS = 100
LEARNING_RATE = 1e-4
SMOOTHING = 0.7  # Label smoothing factor

# Enable mixed precision training
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# Restrict TensorFlow to only use needed GPU memory
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# Clear memory
gc.collect()
tf.keras.backend.clear_session()

# Paths
authentic_paths = [
    r"C:\Users\Rohit Vardhan\Documents\EOC & MFC\datasets\MICC-F2000\auth"
]
tampered_paths = [
    r"C:\Users\Rohit Vardhan\Documents\EOC & MFC\datasets\MICC-F2000\tamp"
]

# Load Data
def collect_image_files(authentic_paths, tampered_paths):
    authentic_files, tampered_files = [], []
    for path in authentic_paths + tampered_paths:
        for subdir, _, files in os.walk(path):
            for file in files:
                if file.lower().endswith(('.png', '.jpeg', '.jpg', '.tif')):
                    full_path = os.path.join(subdir, file)
                    (authentic_files if path in authentic_paths else tampered_files).append(full_path)
    print(f"Number of authentic images found: {len(authentic_files)}")
    print(f"Number of tampered images found: {len(tampered_files)}")
    return authentic_files, tampered_files

authentic_files, tampered_files = collect_image_files(authentic_paths, tampered_paths)
all_files = authentic_files + tampered_files
all_labels = [0] * len(authentic_files) + [1] * len(tampered_files)

print(f"Total images before oversampling: {len(all_files)}")

# Handle Imbalance
oversampler = RandomOverSampler(random_state=42)
all_files, all_labels = oversampler.fit_resample(np.array(all_files).reshape(-1, 1), np.array(all_labels))
all_files = all_files.flatten()

print(f"Total images after oversampling: {len(all_files)}")

# Split data
train_files, test_files, train_labels, test_labels = train_test_split(
    all_files, all_labels, test_size=0.2, random_state=42, stratify=all_labels)

print(f"Training images: {len(train_files)}")
print(f"Testing images: {len(test_files)}")

# Data Generator with Augmentation
class CustomImageDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, image_files, labels, batch_size, image_size, shuffle=True, augment=False):
        self.image_files = np.array(image_files)
        self.labels = np.array(labels).reshape(-1, 1)
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.augment = augment
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.image_files) / self.batch_size))

    def __getitem__(self, idx):
        batch_indices = self.indices[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_images, batch_labels = [], []
        for i in batch_indices:
            img = cv2.imread(self.image_files[i], cv2.IMREAD_COLOR)  # Read as color image
            if img is not None:
                img = cv2.resize(img, self.image_size)
                if self.augment:
                    img = self.augment_image(img)  # Apply augmentation
                batch_images.append(img)
                batch_labels.append(self.labels[i])
        return np.array(batch_images, dtype=np.float16) / 255.0, np.array(batch_labels)

    def augment_image(self, img):
        img = tf.image.random_flip_left_right(img)
        img = tf.image.random_brightness(img, max_delta=0.1)
        img = tf.image.random_contrast(img, lower=0.8, upper=1.2)
        return img

    def on_epoch_end(self):
        self.indices = np.arange(len(self.image_files))
        if self.shuffle:
            np.random.shuffle(self.indices)

train_gen = CustomImageDataGenerator(train_files, train_labels, BATCH_SIZE, IMAGE_SIZE, augment=True)
test_gen = CustomImageDataGenerator(test_files, test_labels, BATCH_SIZE, IMAGE_SIZE, shuffle=False)

def extract_from_generator(generator):
    X, y = [], []
    
    for batch_x, batch_y in generator:
        X.extend(batch_x)
        y.extend(batch_y)

        # Break if we've gathered enough samples
        if len(X) >= len(generator.labels):  # Use labels length as a stopping condition
            break
    
    return np.array(X), np.array(y)
    
X_train, y_train = extract_from_generator(train_gen)
X_test, y_test = extract_from_generator(test_gen)

X_train = X_train / 255.0
X_test = X_test / 255.0


import numpy as np
import keras.backend as K
from keras.layers import Input, Conv2D, MaxPool2D, DepthwiseConv2D, BatchNormalization, Activation, Concatenate, GlobalAveragePooling2D, Dense, Lambda, Flatten, Reshape, MultiHeadAttention, Dropout, LayerNormalization, Add
from keras.models import Model

# Function for Channel Shuffle
def channel_shuffle(x):
    height, width, channels = x.shape.as_list()[1:]
    channels_per_split = channels // 2
    x = tf.reshape(x, [-1, height, width, 2, channels_per_split])
    x = tf.transpose(x, perm=(0, 1, 2, 4, 3))
    x = tf.reshape(x, [-1, height, width, channels])
    return x

# ShuffleNet Unit (Shuffle Block)
def shuffle_unit(inputs, out_channels, bottleneck_ratio, strides=2, stage=1, block=1):
    if K.image_data_format() == 'channels_last':
        bn_axis = -1
    else:
        raise ValueError('Only channels last supported')

    prefix = f'stage{stage}_block{block}'
    bottleneck_channels = int(out_channels * bottleneck_ratio)
    
    x = Conv2D(bottleneck_channels, kernel_size=(1,1), strides=1, padding='same', name=f'{prefix}_1x1conv_1')(inputs)
    x = BatchNormalization(axis=bn_axis, name=f'{prefix}_bn_1x1conv_1')(x)
    x = Activation('relu', name=f'{prefix}_relu_1x1conv_1')(x)
    
    x = DepthwiseConv2D(kernel_size=3, strides=strides, padding='same', name=f'{prefix}_3x3dwconv')(x)
    x = BatchNormalization(axis=bn_axis, name=f'{prefix}_bn_3x3dwconv')(x)
    
    x = Conv2D(bottleneck_channels, kernel_size=1, strides=1, padding='same', name=f'{prefix}_1x1conv_2')(x)
    x = BatchNormalization(axis=bn_axis, name=f'{prefix}_bn_1x1conv_2')(x)
    x = Activation('relu', name=f'{prefix}_relu_1x1conv_2')(x)

    ret = Lambda(channel_shuffle, output_shape=lambda s: s, name=f'{prefix}_channel_shuffle')(x)
    return ret

# Transformer Block
def TransformerBlock(inputs, num_heads=8, ff_dim=512, dropout_rate=0.1):
    attn_output = MultiHeadAttention(num_heads=num_heads, key_dim=inputs.shape[-1] // num_heads)(inputs, inputs)
    attn_output = Dropout(dropout_rate)(attn_output)
    out1 = Add()([inputs, attn_output])
    out1 = LayerNormalization(epsilon=1e-6)(out1)
    
    ffn_output = Dense(ff_dim, activation='relu')(out1)
    ffn_output = Dense(inputs.shape[-1])(ffn_output)  # Match input shape
    ffn_output = Dropout(dropout_rate)(ffn_output)
    
    out2 = Add()([out1, ffn_output])
    out2 = LayerNormalization(epsilon=1e-6)(out2)
    return out2

# ShuffleNetV2 Backbone
def ShuffleNetV2(input_shape=(32,32,3)):
    img_input = Input(shape=input_shape)
    
    x = Conv2D(24, kernel_size=(3, 3), padding='same', use_bias=False, strides=(2, 2), activation='relu', name='conv1')(img_input)
    x = MaxPool2D(pool_size=(3, 3), strides=(2, 2), padding='same', name='maxpool1')(x)
    x = shuffle_unit(x, out_channels=116, strides=2, bottleneck_ratio=1, stage=2, block=1)
    
    x = Conv2D(1024, kernel_size=1, padding='same', strides=1, activation='relu', name='conv_final')(x)
    x = GlobalAveragePooling2D(name='global_avg_pool')(x)
    
    return Model(img_input, x, name='ShuffleNetV2')

# Hybrid Model with ShuffleNet and Transformer
def HybridModel(input_shape=(224, 224, 3)):  # Changed to 3 channels
    shufflenet = ShuffleNetV2(input_shape=input_shape)
    shufflenet_output = shufflenet.output  # (batch_size, features)

    # Reshape for Transformer block
    reshaped_output = Reshape((1, shufflenet_output.shape[-1]))(shufflenet_output)

    # Pass through Transformer block
    transformer_output = TransformerBlock(reshaped_output)

    # Flatten and classification layers
    transformer_output = Flatten()(transformer_output)
    x = Dense(512, activation='relu')(transformer_output)
    x = Dropout(0.3)(x)
    x = Dense(1, activation='sigmoid')(x)  # Single output neuron with sigmoid activation

    model = Model(inputs=shufflenet.input, outputs=x)
    return model

# Create and compile the model
model = HybridModel(input_shape=(224, 224, 3))  # Changed to 3 channels
model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss=BinaryCrossentropy(label_smoothing=SMOOTHING),  # Use built-in function
    metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
)

# Print model summary
print(model.summary())

# Callbacks
class ClearMemory(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        gc.collect()
        tf.keras.backend.clear_session()

clear_memory = ClearMemory()

early_stopping = EarlyStopping(monitor='val_auc', patience=25, restore_best_weights=True, mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_auc', factor=0.5, patience=5, min_lr=1e-7, verbose=1, mode='max')
model_checkpoint = ModelCheckpoint('best_hybrid_model.keras', monitor='val_auc', mode='max', save_best_only=True, verbose=1)

# Train Model
history = model.fit(
    train_gen,
    validation_data=test_gen,
    epochs=EPOCHS,
    callbacks=[early_stopping, reduce_lr, model_checkpoint, clear_memory]
)

# Save the model
model.save('hybrid_model.keras')
print("Model saved as hybrid_model.keras")

# Evaluate Model
test_preds = model.predict(test_gen)
test_preds = (test_preds > 0.5).astype(int)  # Convert probabilities to binary predictions

# Calculate metrics
accuracy = accuracy_score(test_labels, test_preds)
precision = precision_score(test_labels, test_preds)
recall = recall_score(test_labels, test_preds)
f1 = f1_score(test_labels, test_preds)
roc_auc = roc_auc_score(test_labels, test_preds)

# Confusion Matrix
conf_matrix = confusion_matrix(test_labels, test_preds)

# Classification Report
class_report = classification_report(test_labels, test_preds, target_names=['Authentic', 'Tampered'])

# ROC Curve
fpr, tpr, thresholds = roc_curve(test_labels, test_preds)

# AUC Curve plotting
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC Curve (AUC = {roc_auc:.4f})', color='blue')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUC Curve')
plt.legend(loc='lower right')
plt.grid(alpha=0.3)
plt.show()

# Print all results
print("\n=== Evaluation Metrics ===")
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test F1-Score: {f1:.4f}")
print(f"Test ROC-AUC: {roc_auc:.4f}")

print("\n=== Confusion Matrix ===")
print(conf_matrix)

print("\n=== Classification Report ===")
print(class_report)

# Plot Confusion Matrix
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Authentic', 'Tampered'], yticklabels=['Authentic', 'Tampered'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Plot Precision, Recall, and F1-Score in a bar graph
metrics = ['Precision', 'Recall', 'F1-Score']
values = [precision, recall, f1]

plt.figure(figsize=(8, 5))
bars = plt.bar(metrics, values, color=['blue', 'green', 'orange'])

# Add values on top of the bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.4f}',
             ha='center', va='bottom', fontsize=10)

plt.title('Precision, Recall, and F1-Score')
plt.xlabel('Metrics')
plt.ylabel('Score')
plt.ylim(0, 1)  # Set y-axis limits between 0 and 1
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Plot Model Loss and Accuracy over Epochs
plt.figure(figsize=(10, 5))

# Plot Train vs Validation Accuracy
plt.figure(figsize=(8,5))
plt.plot(history.history['accuracy'], label='Train Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Train vs Validation Accuracy')
plt.legend()
plt.grid()
plt.show()

# Plot Train vs Validation Loss
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Train vs Validation Loss')
plt.legend()
plt.grid()
plt.show()

plt.tight_layout()
plt.show()
# Out:
# WARNING:tensorflow:From C:\Users\Rohit Vardhan\anaconda3\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Number of authentic images found: 1300
# Number of tampered images found: 700
# Total images before oversampling: 2000
# Total images after oversampling: 2600
# Training images: 2080
# Testing images: 520
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1 (Conv2D)      │ (None, 112, 112,  │        648 │ input_layer[0][0] │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ maxpool1            │ (None, 56, 56,    │          0 │ conv1[0][0]       │
# │ (MaxPooling2D)      │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_1x1c… │ (None, 56, 56,    │      2,900 │ maxpool1[0][0]    │
# │ (Conv2D)            │ 116)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_bn_1… │ (None, 56, 56,    │        464 │ stage2_block1_1x… │
# │ (BatchNormalizatio… │ 116)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_relu… │ (None, 56, 56,    │          0 │ stage2_block1_bn… │
# │ (Activation)        │ 116)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_3x3d… │ (None, 28, 28,    │      1,160 │ stage2_block1_re… │
# │ (DepthwiseConv2D)   │ 116)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_bn_3… │ (None, 28, 28,    │        464 │ stage2_block1_3x… │
# │ (BatchNormalizatio… │ 116)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_1x1c… │ (None, 28, 28,    │     13,572 │ stage2_block1_bn… │
# │ (Conv2D)            │ 116)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_bn_1… │ (None, 28, 28,    │        464 │ stage2_block1_1x… │
# │ (BatchNormalizatio… │ 116)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_relu… │ (None, 28, 28,    │          0 │ stage2_block1_bn… │
# │ (Activation)        │ 116)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_chan… │ (None, 28, 28,    │          0 │ stage2_block1_re… │
# │ (Lambda)            │ 116)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_final (Conv2D) │ (None, 28, 28,    │    119,808 │ stage2_block1_ch… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_avg_pool     │ (None, 1024)      │          0 │ conv_final[0][0]  │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1024)   │          0 │ global_avg_pool[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 1, 1024)   │  4,198,400 │ reshape[0][0],    │
# │ (MultiHeadAttentio… │                   │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1, 1024)   │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1, 1024)   │          0 │ reshape[0][0],    │
# │                     │                   │            │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 1, 1024)   │      2,048 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1, 512)    │    524,800 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1, 1024)   │    525,312 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 1, 1024)   │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 1, 1024)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 1, 1024)   │      2,048 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 1024)      │          0 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 512)       │    524,800 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 512)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1)         │        513 │ dropout_3[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,917,401 (22.57 MB)
#  Trainable params: 5,916,705 (22.57 MB)
#  Non-trainable params: 696 (2.72 KB)
# None
# C:\Users\Rohit Vardhan\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5082 - auc: 0.5136 - loss: 0.8626
# Epoch 1: val_auc improved from -inf to 0.55982, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 99s 1s/step - accuracy: 0.5085 - auc: 0.5139 - loss: 0.8612 - val_accuracy: 0.5000 - val_auc: 0.5598 - val_loss: 0.7120 - learning_rate: 1.0000e-04
# Epoch 2/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5709 - auc: 0.6033 - loss: 0.7017
# Epoch 2: val_auc did not improve from 0.55982
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.5711 - auc: 0.6036 - loss: 0.7016 - val_accuracy: 0.5000 - val_auc: 0.5419 - val_loss: 0.7000 - learning_rate: 1.0000e-04
# Epoch 3/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5827 - auc: 0.6077 - loss: 0.6970
# Epoch 3: val_auc improved from 0.55982 to 0.61434, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.5827 - auc: 0.6079 - loss: 0.6969 - val_accuracy: 0.5077 - val_auc: 0.6143 - val_loss: 0.6939 - learning_rate: 1.0000e-04
# Epoch 4/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6211 - auc: 0.6698 - loss: 0.6897
# Epoch 4: val_auc did not improve from 0.61434
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.6210 - auc: 0.6699 - loss: 0.6897 - val_accuracy: 0.4923 - val_auc: 0.5334 - val_loss: 0.6926 - learning_rate: 1.0000e-04
# Epoch 5/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6413 - auc: 0.7012 - loss: 0.6870
# Epoch 5: val_auc did not improve from 0.61434
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.6414 - auc: 0.7013 - loss: 0.6870 - val_accuracy: 0.5077 - val_auc: 0.5688 - val_loss: 0.7016 - learning_rate: 1.0000e-04
# Epoch 6/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6403 - auc: 0.7194 - loss: 0.6863
# Epoch 6: val_auc did not improve from 0.61434
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.6404 - auc: 0.7194 - loss: 0.6863 - val_accuracy: 0.5173 - val_auc: 0.5290 - val_loss: 0.7024 - learning_rate: 1.0000e-04
# Epoch 7/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6835 - auc: 0.7368 - loss: 0.6860
# Epoch 7: val_auc did not improve from 0.61434
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.6833 - auc: 0.7367 - loss: 0.6860 - val_accuracy: 0.5288 - val_auc: 0.5562 - val_loss: 0.7013 - learning_rate: 1.0000e-04
# Epoch 8/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7028 - auc: 0.7806 - loss: 0.6828
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 8: val_auc did not improve from 0.61434
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.7028 - auc: 0.7804 - loss: 0.6828 - val_accuracy: 0.5231 - val_auc: 0.6007 - val_loss: 0.7005 - learning_rate: 1.0000e-04
# Epoch 9/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6791 - auc: 0.7602 - loss: 0.6835
# Epoch 9: val_auc improved from 0.61434 to 0.71771, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.6790 - auc: 0.7602 - loss: 0.6835 - val_accuracy: 0.6096 - val_auc: 0.7177 - val_loss: 0.6902 - learning_rate: 5.0000e-05
# Epoch 10/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7164 - auc: 0.8048 - loss: 0.6817
# Epoch 10: val_auc improved from 0.71771 to 0.80510, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.7164 - auc: 0.8047 - loss: 0.6817 - val_accuracy: 0.7000 - val_auc: 0.8051 - val_loss: 0.6820 - learning_rate: 5.0000e-05
# Epoch 11/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7506 - auc: 0.8169 - loss: 0.6807
# Epoch 11: val_auc improved from 0.80510 to 0.82856, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.7505 - auc: 0.8169 - loss: 0.6806 - val_accuracy: 0.7423 - val_auc: 0.8286 - val_loss: 0.6807 - learning_rate: 5.0000e-05
# Epoch 12/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7240 - auc: 0.8077 - loss: 0.6813
# Epoch 12: val_auc improved from 0.82856 to 0.85107, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.7240 - auc: 0.8077 - loss: 0.6813 - val_accuracy: 0.7654 - val_auc: 0.8511 - val_loss: 0.6793 - learning_rate: 5.0000e-05
# Epoch 13/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7398 - auc: 0.8198 - loss: 0.6804
# Epoch 13: val_auc did not improve from 0.85107
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.7399 - auc: 0.8199 - loss: 0.6804 - val_accuracy: 0.7981 - val_auc: 0.8449 - val_loss: 0.6784 - learning_rate: 5.0000e-05
# Epoch 14/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7580 - auc: 0.8416 - loss: 0.6788
# Epoch 14: val_auc improved from 0.85107 to 0.88680, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.7578 - auc: 0.8414 - loss: 0.6788 - val_accuracy: 0.7154 - val_auc: 0.8868 - val_loss: 0.6791 - learning_rate: 5.0000e-05
# Epoch 15/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7245 - auc: 0.8106 - loss: 0.6808
# Epoch 15: val_auc improved from 0.88680 to 0.88785, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.7247 - auc: 0.8108 - loss: 0.6808 - val_accuracy: 0.7885 - val_auc: 0.8878 - val_loss: 0.6763 - learning_rate: 5.0000e-05
# Epoch 16/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7588 - auc: 0.8466 - loss: 0.6781
# Epoch 16: val_auc improved from 0.88785 to 0.90203, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.7589 - auc: 0.8467 - loss: 0.6781 - val_accuracy: 0.7731 - val_auc: 0.9020 - val_loss: 0.6766 - learning_rate: 5.0000e-05
# Epoch 17/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7788 - auc: 0.8609 - loss: 0.6767
# Epoch 17: val_auc did not improve from 0.90203
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7787 - auc: 0.8609 - loss: 0.6767 - val_accuracy: 0.7808 - val_auc: 0.8710 - val_loss: 0.6760 - learning_rate: 5.0000e-05
# Epoch 18/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7731 - auc: 0.8553 - loss: 0.6771
# Epoch 18: val_auc improved from 0.90203 to 0.91302, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.7731 - auc: 0.8552 - loss: 0.6771 - val_accuracy: 0.8077 - val_auc: 0.9130 - val_loss: 0.6741 - learning_rate: 5.0000e-05
# Epoch 19/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7960 - auc: 0.8745 - loss: 0.6757
# Epoch 19: val_auc improved from 0.91302 to 0.93377, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.7959 - auc: 0.8743 - loss: 0.6757 - val_accuracy: 0.8692 - val_auc: 0.9338 - val_loss: 0.6709 - learning_rate: 5.0000e-05
# Epoch 20/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8064 - auc: 0.8839 - loss: 0.6744
# Epoch 20: val_auc did not improve from 0.93377
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.8064 - auc: 0.8838 - loss: 0.6744 - val_accuracy: 0.8385 - val_auc: 0.9282 - val_loss: 0.6715 - learning_rate: 5.0000e-05
# Epoch 21/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7951 - auc: 0.8785 - loss: 0.6752
# Epoch 21: val_auc did not improve from 0.93377
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.7953 - auc: 0.8786 - loss: 0.6752 - val_accuracy: 0.8577 - val_auc: 0.9290 - val_loss: 0.6694 - learning_rate: 5.0000e-05
# Epoch 22/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8093 - auc: 0.8897 - loss: 0.6738
# Epoch 22: val_auc did not improve from 0.93377
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.8091 - auc: 0.8895 - loss: 0.6738 - val_accuracy: 0.8615 - val_auc: 0.9158 - val_loss: 0.6704 - learning_rate: 5.0000e-05
# Epoch 23/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8152 - auc: 0.8798 - loss: 0.6748
# Epoch 23: val_auc improved from 0.93377 to 0.93938, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.8152 - auc: 0.8800 - loss: 0.6748 - val_accuracy: 0.8019 - val_auc: 0.9394 - val_loss: 0.6720 - learning_rate: 5.0000e-05
# Epoch 24/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8243 - auc: 0.9061 - loss: 0.6723
# Epoch 24: val_auc improved from 0.93938 to 0.94597, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.8243 - auc: 0.9059 - loss: 0.6723 - val_accuracy: 0.7885 - val_auc: 0.9460 - val_loss: 0.6740 - learning_rate: 5.0000e-05
# Epoch 25/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8482 - auc: 0.9123 - loss: 0.6713
# Epoch 25: val_auc did not improve from 0.94597
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8479 - auc: 0.9121 - loss: 0.6714 - val_accuracy: 0.8404 - val_auc: 0.9273 - val_loss: 0.6690 - learning_rate: 5.0000e-05
# Epoch 26/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8490 - auc: 0.9134 - loss: 0.6711
# Epoch 26: val_auc improved from 0.94597 to 0.95055, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8487 - auc: 0.9132 - loss: 0.6711 - val_accuracy: 0.8865 - val_auc: 0.9506 - val_loss: 0.6676 - learning_rate: 5.0000e-05
# Epoch 27/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8265 - auc: 0.9115 - loss: 0.6716
# Epoch 27: val_auc did not improve from 0.95055
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8266 - auc: 0.9114 - loss: 0.6716 - val_accuracy: 0.8442 - val_auc: 0.9301 - val_loss: 0.6693 - learning_rate: 5.0000e-05
# Epoch 28/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8396 - auc: 0.9197 - loss: 0.6704
# Epoch 28: val_auc did not improve from 0.95055
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8396 - auc: 0.9196 - loss: 0.6705 - val_accuracy: 0.8269 - val_auc: 0.9448 - val_loss: 0.6707 - learning_rate: 5.0000e-05
# Epoch 29/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8605 - auc: 0.9315 - loss: 0.6695
# Epoch 29: val_auc did not improve from 0.95055
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.8605 - auc: 0.9314 - loss: 0.6695 - val_accuracy: 0.8346 - val_auc: 0.9461 - val_loss: 0.6689 - learning_rate: 5.0000e-05
# Epoch 30/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8471 - auc: 0.9198 - loss: 0.6700
# Epoch 30: val_auc improved from 0.95055 to 0.95931, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.8472 - auc: 0.9199 - loss: 0.6700 - val_accuracy: 0.8846 - val_auc: 0.9593 - val_loss: 0.6662 - learning_rate: 5.0000e-05
# Epoch 31/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8695 - auc: 0.9393 - loss: 0.6680
# Epoch 31: val_auc improved from 0.95931 to 0.96696, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8695 - auc: 0.9392 - loss: 0.6680 - val_accuracy: 0.9038 - val_auc: 0.9670 - val_loss: 0.6651 - learning_rate: 5.0000e-05
# Epoch 32/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8581 - auc: 0.9365 - loss: 0.6690
# Epoch 32: val_auc did not improve from 0.96696
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8581 - auc: 0.9365 - loss: 0.6690 - val_accuracy: 0.8923 - val_auc: 0.9621 - val_loss: 0.6641 - learning_rate: 5.0000e-05
# Epoch 33/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8476 - auc: 0.9284 - loss: 0.6691
# Epoch 33: val_auc did not improve from 0.96696
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.8478 - auc: 0.9284 - loss: 0.6691 - val_accuracy: 0.9115 - val_auc: 0.9604 - val_loss: 0.6641 - learning_rate: 5.0000e-05
# Epoch 34/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8543 - auc: 0.9264 - loss: 0.6696
# Epoch 34: val_auc did not improve from 0.96696
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8545 - auc: 0.9264 - loss: 0.6696 - val_accuracy: 0.9000 - val_auc: 0.9439 - val_loss: 0.6677 - learning_rate: 5.0000e-05
# Epoch 35/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8849 - auc: 0.9417 - loss: 0.6674
# Epoch 35: val_auc improved from 0.96696 to 0.97089, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.8849 - auc: 0.9417 - loss: 0.6674 - val_accuracy: 0.9538 - val_auc: 0.9709 - val_loss: 0.6625 - learning_rate: 5.0000e-05
# Epoch 36/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8887 - auc: 0.9498 - loss: 0.6666
# Epoch 36: val_auc did not improve from 0.97089
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8887 - auc: 0.9497 - loss: 0.6666 - val_accuracy: 0.9577 - val_auc: 0.9687 - val_loss: 0.6619 - learning_rate: 5.0000e-05
# Epoch 37/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8995 - auc: 0.9501 - loss: 0.6660
# Epoch 37: val_auc improved from 0.97089 to 0.97215, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 98s 1s/step - accuracy: 0.8994 - auc: 0.9500 - loss: 0.6660 - val_accuracy: 0.9077 - val_auc: 0.9722 - val_loss: 0.6617 - learning_rate: 5.0000e-05
# Epoch 38/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9056 - auc: 0.9611 - loss: 0.6642
# Epoch 38: val_auc did not improve from 0.97215
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9054 - auc: 0.9609 - loss: 0.6643 - val_accuracy: 0.9058 - val_auc: 0.9718 - val_loss: 0.6637 - learning_rate: 5.0000e-05
# Epoch 39/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8931 - auc: 0.9460 - loss: 0.6666
# Epoch 39: val_auc did not improve from 0.97215
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 118s 2s/step - accuracy: 0.8931 - auc: 0.9460 - loss: 0.6666 - val_accuracy: 0.9231 - val_auc: 0.9710 - val_loss: 0.6619 - learning_rate: 5.0000e-05
# Epoch 40/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9177 - auc: 0.9558 - loss: 0.6648
# Epoch 40: val_auc improved from 0.97215 to 0.97302, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 114s 2s/step - accuracy: 0.9174 - auc: 0.9557 - loss: 0.6648 - val_accuracy: 0.9269 - val_auc: 0.9730 - val_loss: 0.6635 - learning_rate: 5.0000e-05
# Epoch 41/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9157 - auc: 0.9649 - loss: 0.6639
# Epoch 41: val_auc did not improve from 0.97302
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9155 - auc: 0.9647 - loss: 0.6639 - val_accuracy: 0.9019 - val_auc: 0.9646 - val_loss: 0.6632 - learning_rate: 5.0000e-05
# Epoch 42/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8978 - auc: 0.9474 - loss: 0.6660
# Epoch 42: val_auc did not improve from 0.97302
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.8976 - auc: 0.9473 - loss: 0.6660 - val_accuracy: 0.9250 - val_auc: 0.9707 - val_loss: 0.6619 - learning_rate: 5.0000e-05
# Epoch 43/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8989 - auc: 0.9448 - loss: 0.6661
# Epoch 43: val_auc improved from 0.97302 to 0.97366, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.8989 - auc: 0.9449 - loss: 0.6661 - val_accuracy: 0.9115 - val_auc: 0.9737 - val_loss: 0.6649 - learning_rate: 5.0000e-05
# Epoch 44/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9092 - auc: 0.9560 - loss: 0.6645
# Epoch 44: val_auc did not improve from 0.97366
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9092 - auc: 0.9559 - loss: 0.6645 - val_accuracy: 0.9269 - val_auc: 0.9703 - val_loss: 0.6619 - learning_rate: 5.0000e-05
# Epoch 45/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8929 - auc: 0.9534 - loss: 0.6650
# Epoch 45: val_auc improved from 0.97366 to 0.97802, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.8929 - auc: 0.9534 - loss: 0.6650 - val_accuracy: 0.9346 - val_auc: 0.9780 - val_loss: 0.6604 - learning_rate: 5.0000e-05
# Epoch 46/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9109 - auc: 0.9622 - loss: 0.6634
# Epoch 46: val_auc did not improve from 0.97802
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9109 - auc: 0.9622 - loss: 0.6634 - val_accuracy: 0.9192 - val_auc: 0.9700 - val_loss: 0.6616 - learning_rate: 5.0000e-05
# Epoch 47/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9251 - auc: 0.9581 - loss: 0.6632
# Epoch 47: val_auc did not improve from 0.97802
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9249 - auc: 0.9581 - loss: 0.6632 - val_accuracy: 0.9288 - val_auc: 0.9744 - val_loss: 0.6611 - learning_rate: 5.0000e-05
# Epoch 48/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8977 - auc: 0.9544 - loss: 0.6644
# Epoch 48: val_auc did not improve from 0.97802
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.8978 - auc: 0.9544 - loss: 0.6644 - val_accuracy: 0.9404 - val_auc: 0.9682 - val_loss: 0.6614 - learning_rate: 5.0000e-05
# Epoch 49/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9191 - auc: 0.9615 - loss: 0.6637
# Epoch 49: val_auc did not improve from 0.97802
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9190 - auc: 0.9615 - loss: 0.6637 - val_accuracy: 0.9481 - val_auc: 0.9659 - val_loss: 0.6613 - learning_rate: 5.0000e-05
# Epoch 50/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9297 - auc: 0.9669 - loss: 0.6622
# Epoch 50: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 50: val_auc did not improve from 0.97802
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 118s 2s/step - accuracy: 0.9296 - auc: 0.9669 - loss: 0.6622 - val_accuracy: 0.9442 - val_auc: 0.9728 - val_loss: 0.6593 - learning_rate: 5.0000e-05
# Epoch 51/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9216 - auc: 0.9642 - loss: 0.6626
# Epoch 51: val_auc improved from 0.97802 to 0.98016, saving model to best_hybrid_model.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9216 - auc: 0.9642 - loss: 0.6626 - val_accuracy: 0.9673 - val_auc: 0.9802 - val_loss: 0.6573 - learning_rate: 2.5000e-05
# Epoch 52/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9253 - auc: 0.9650 - loss: 0.6616
# Epoch 52: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9252 - auc: 0.9649 - loss: 0.6616 - val_accuracy: 0.9327 - val_auc: 0.9777 - val_loss: 0.6596 - learning_rate: 2.5000e-05
# Epoch 53/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9360 - auc: 0.9674 - loss: 0.6610
# Epoch 53: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.9361 - auc: 0.9675 - loss: 0.6610 - val_accuracy: 0.9481 - val_auc: 0.9785 - val_loss: 0.6581 - learning_rate: 2.5000e-05
# Epoch 54/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9429 - auc: 0.9746 - loss: 0.6602
# Epoch 54: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9428 - auc: 0.9746 - loss: 0.6602 - val_accuracy: 0.9596 - val_auc: 0.9767 - val_loss: 0.6567 - learning_rate: 2.5000e-05
# Epoch 55/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9383 - auc: 0.9727 - loss: 0.6607
# Epoch 55: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9383 - auc: 0.9726 - loss: 0.6607 - val_accuracy: 0.9385 - val_auc: 0.9795 - val_loss: 0.6593 - learning_rate: 2.5000e-05
# Epoch 56/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9280 - auc: 0.9682 - loss: 0.6616
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 56: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9281 - auc: 0.9683 - loss: 0.6616 - val_accuracy: 0.9538 - val_auc: 0.9758 - val_loss: 0.6579 - learning_rate: 2.5000e-05
# Epoch 57/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9557 - auc: 0.9772 - loss: 0.6590
# Epoch 57: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9556 - auc: 0.9771 - loss: 0.6590 - val_accuracy: 0.9481 - val_auc: 0.9722 - val_loss: 0.6578 - learning_rate: 1.2500e-05
# Epoch 58/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9543 - auc: 0.9771 - loss: 0.6595
# Epoch 58: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9542 - auc: 0.9771 - loss: 0.6595 - val_accuracy: 0.9519 - val_auc: 0.9795 - val_loss: 0.6571 - learning_rate: 1.2500e-05
# Epoch 59/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9516 - auc: 0.9807 - loss: 0.6585
# Epoch 59: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.9516 - auc: 0.9807 - loss: 0.6585 - val_accuracy: 0.9538 - val_auc: 0.9786 - val_loss: 0.6564 - learning_rate: 1.2500e-05
# Epoch 60/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9373 - auc: 0.9692 - loss: 0.6600
# Epoch 60: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - accuracy: 0.9374 - auc: 0.9693 - loss: 0.6600 - val_accuracy: 0.9596 - val_auc: 0.9761 - val_loss: 0.6571 - learning_rate: 1.2500e-05
# Epoch 61/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.9504 - auc: 0.9725 - loss: 0.6599
# Epoch 61: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 61: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 437s 7s/step - accuracy: 0.9503 - auc: 0.9725 - loss: 0.6599 - val_accuracy: 0.9288 - val_auc: 0.9793 - val_loss: 0.6607 - learning_rate: 1.2500e-05
# Epoch 62/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9466 - auc: 0.9708 - loss: 0.6595
# Epoch 62: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9467 - auc: 0.9709 - loss: 0.6595 - val_accuracy: 0.9500 - val_auc: 0.9776 - val_loss: 0.6573 - learning_rate: 6.2500e-06
# Epoch 63/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9618 - auc: 0.9756 - loss: 0.6586
# Epoch 63: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 118s 2s/step - accuracy: 0.9617 - auc: 0.9756 - loss: 0.6586 - val_accuracy: 0.9481 - val_auc: 0.9785 - val_loss: 0.6571 - learning_rate: 6.2500e-06
# Epoch 64/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9491 - auc: 0.9761 - loss: 0.6587
# Epoch 64: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.9492 - auc: 0.9762 - loss: 0.6587 - val_accuracy: 0.9615 - val_auc: 0.9775 - val_loss: 0.6554 - learning_rate: 6.2500e-06
# Epoch 65/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9560 - auc: 0.9712 - loss: 0.6590
# Epoch 65: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - accuracy: 0.9559 - auc: 0.9712 - loss: 0.6590 - val_accuracy: 0.9615 - val_auc: 0.9775 - val_loss: 0.6558 - learning_rate: 6.2500e-06
# Epoch 66/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9499 - auc: 0.9792 - loss: 0.6581
# Epoch 66: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
#
# Epoch 66: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 114s 2s/step - accuracy: 0.9499 - auc: 0.9792 - loss: 0.6581 - val_accuracy: 0.9500 - val_auc: 0.9789 - val_loss: 0.6571 - learning_rate: 6.2500e-06
# Epoch 67/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9553 - auc: 0.9758 - loss: 0.6588
# Epoch 67: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.9553 - auc: 0.9759 - loss: 0.6587 - val_accuracy: 0.9654 - val_auc: 0.9749 - val_loss: 0.6557 - learning_rate: 3.1250e-06
# Epoch 68/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9512 - auc: 0.9765 - loss: 0.6584
# Epoch 68: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - accuracy: 0.9512 - auc: 0.9765 - loss: 0.6584 - val_accuracy: 0.9654 - val_auc: 0.9788 - val_loss: 0.6554 - learning_rate: 3.1250e-06
# Epoch 69/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9588 - auc: 0.9761 - loss: 0.6582
# Epoch 69: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9588 - auc: 0.9761 - loss: 0.6582 - val_accuracy: 0.9615 - val_auc: 0.9786 - val_loss: 0.6560 - learning_rate: 3.1250e-06
# Epoch 70/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9594 - auc: 0.9844 - loss: 0.6572
# Epoch 70: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.9593 - auc: 0.9843 - loss: 0.6572 - val_accuracy: 0.9538 - val_auc: 0.9761 - val_loss: 0.6565 - learning_rate: 3.1250e-06
# Epoch 71/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9535 - auc: 0.9755 - loss: 0.6585
# Epoch 71: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
#
# Epoch 71: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 128s 2s/step - accuracy: 0.9535 - auc: 0.9755 - loss: 0.6585 - val_accuracy: 0.9481 - val_auc: 0.9771 - val_loss: 0.6572 - learning_rate: 3.1250e-06
# Epoch 72/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9527 - auc: 0.9728 - loss: 0.6587
# Epoch 72: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.9527 - auc: 0.9728 - loss: 0.6587 - val_accuracy: 0.9558 - val_auc: 0.9763 - val_loss: 0.6565 - learning_rate: 1.5625e-06
# Epoch 73/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9538 - auc: 0.9743 - loss: 0.6586
# Epoch 73: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.9538 - auc: 0.9743 - loss: 0.6586 - val_accuracy: 0.9577 - val_auc: 0.9770 - val_loss: 0.6563 - learning_rate: 1.5625e-06
# Epoch 74/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9619 - auc: 0.9814 - loss: 0.6577
# Epoch 74: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9619 - auc: 0.9813 - loss: 0.6577 - val_accuracy: 0.9596 - val_auc: 0.9773 - val_loss: 0.6558 - learning_rate: 1.5625e-06
# Epoch 75/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9591 - auc: 0.9752 - loss: 0.6583
# Epoch 75: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - accuracy: 0.9590 - auc: 0.9752 - loss: 0.6583 - val_accuracy: 0.9558 - val_auc: 0.9772 - val_loss: 0.6564 - learning_rate: 1.5625e-06
# Epoch 76/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9443 - auc: 0.9743 - loss: 0.6590
# Epoch 76: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
#
# Epoch 76: val_auc did not improve from 0.98016
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.9445 - auc: 0.9744 - loss: 0.6590 - val_accuracy: 0.9558 - val_auc: 0.9770 - val_loss: 0.6562 - learning_rate: 1.5625e-06
# Model saved as hybrid_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step
# === Evaluation Metrics ===
# Test Accuracy: 0.9673
# Test Precision: 0.9483
# Test Recall: 0.9885
# Test F1-Score: 0.9680
# Test ROC-AUC: 0.9673
#
# === Confusion Matrix ===
# [[246  14]
#  [  3 257]]
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#    Authentic       0.99      0.95      0.97       260
#     Tampered       0.95      0.99      0.97       260
#
#     accuracy                           0.97       520
#    macro avg       0.97      0.97      0.97       520
# weighted avg       0.97      0.97      0.97       520
